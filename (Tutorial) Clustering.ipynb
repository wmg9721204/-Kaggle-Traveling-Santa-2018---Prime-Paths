# %% [markdown]
# **Official Documentation**: https://clusteringjl.readthedocs.io/en/latest/index.html

# %%
using Clustering

# %% [markdown]
# **Basic inputs:**
# 1. X, an array of dimension d x N, where each column represents a point in dimension d
# 2. D, the distance matrix, recording the distances between the points
# 3. k, number of clusters
# 3. (Optional) initseeds(:kmcen, X, k), initialize the initial points (seeds) before the iterations

# %%
using LinearAlgebra # "norm"
N = 5000
X = rand(2,N)
## D = [norm(X[:,i]-X[:,j]) for i=1:N, j = 1:N]; ## D is not used in kmeans

# %%
k = 50
## initseeds(:kmcen, X, k) ## initialize the points
R = kmeans(X, k) ##; maxiter = 2000, display=:iter) ## R = Result
# Out:
# KmeansResult{Float64}([0.368451 0.764873 … 0.0892876 0.269491; 0.424365 0.771516 … 0.203335 0.803507], [25, 29, 18, 39, 21, 19, 31, 25, 8, 17  …  27, 29, 39, 34, 46, 17, 45, 35, 24, 27], [0.000828645, 0.00329169, 0.00752864, 0.00251532, 0.00120369, 0.00244944, 0.00391675, 0.000380992, 0.0049973, 0.00537855  …  0.00377966, 0.00124255, 0.00182683, 0.00158376, 0.00127812, 0.00208668, 0.0032218, 0.00774143, 0.00354022, 0.00556056], [119, 89, 119, 95, 92, 97, 107, 103, 115, 124  …  134, 107, 80, 85, 111, 91, 112, 99, 88, 114], [119.0, 89.0, 119.0, 95.0, 92.0, 97.0, 107.0, 103.0, 115.0, 124.0  …  134.0, 107.0, 80.0, 85.0, 111.0, 91.0, 112.0, 99.0, 88.0, 114.0], 16.07636817231873, 35, true)

# %%
A = assignments(R) ## the assignments of the points
N = nclusters(R) ## number of clusters
C = counts(R); ## size of each cluster

# %%
Cluster_Dic = Dict(i=>Int[] for i=1:k)
for i=1:k
    Cluster_Dic[i] = findall(A.==i)
end
Cluster_Dic;

# %%
using Plots
plotly()
# Out:
# Plots.PlotlyBackend()

# %%
scatter()
for i=1:k
    scatter!(X[1,Cluster_Dic[i]], X[2,Cluster_Dic[i]], label = "Cluster $i", markersize = 2)
end
scatter!()
# Out:
#     <div id="fc16c8cd-9fe9-4933-9666-1943b4ef7ac9" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('fc16c8cd-9fe9-4933-9666-1943b4ef7ac9');
#     Plotly.plot(PLOT, [{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x":[0.33698083156848635,0.42659085446515266,0.3721389324354971,0.3227153543912038,0.32853512085371595,0.3951991673961952,0.3848159120811736,0.4392343645841572,0.3673602444412183,0.35829858141247883,0.32703321272363994,0.41569397268765296,0.3441342480862313,0.3324546854928485,0.3733807552240582,0.3001493418155894,0.40830348516561465,0.379589197598744,0.34847687759224644,0.32280785874843443,0.28092723444134493,0.37742675060145303,0.3162348684998473,0.4089181944135727,0.3072256282841268,0.3804211174246672,0.3723114881822398,0.3924719719199792,0.4423610412415988,0.3000487262145799,0.36038797554945146,0.34910125577637663,0.4243281051047616,0.42116736790106923,0.38739484233996646,0.3879006582311273,0.31673948312878,0.3274032617405902,0.41467632816107125,0.316138817946612,0.2917316853386023,0.388022090367959,0.32689528079202024,0.30999344784003946,0.36692876621159076,0.3905052253402368,0.38880444820924254,0.3718575667432811,0.36047952454365184,0.42523098528255776,0.41266401203983927,0.42422874588219117,0.35288290997334704,0.3475156100337311,0.36101855768701063,0.3686065858076488,0.2835246262391331,0.34279885427970247,0.35884521562585214,0.3329957663194414,0.32967775623825757,0.4089345216810938,0.44023265709179293,0.361818818536799,0.2837819354092528,0.4032361641158664,0.3293377873383263,0.374548941899429,0.41773664683712997,0.3416343235275905,0.35993100275529355,0.28453361440329283,0.4352595878798864,0.41593442801894565,0.4287579299988171,0.37945936102645916,0.3840427041301613,0.27668983995644325,0.3234400698657005,0.40943245083643975,0.29653320823445495,0.3314979522025958,0.3763723733664721,0.3645221356594519,0.3184237702337631,0.4350848556968816,0.41284208337215866,0.32818802546624526,0.31957216092222995,0.41708955006064974,0.36579427017392696,0.3396711114088733,0.4349894853854508,0.3784926908029467,0.369989189902028,0.39346926286550077,0.39936206645256966,0.3951724767236451,0.39153628099459103,0.4270734238603,0.3075190269179833,0.397044186532614,0.3279443184453663,0.3337899045261197,0.43396498369435976,0.32978910298486297,0.4104978141022375,0.4033908544857969,0.41516762685749264,0.42941885030666405,0.4258392418917518,0.3968862562017832,0.3600577031986014,0.3457427186063222,0.3971298539362227,0.4043470208027382,0.3421552016868388,0.4400599861495076,0.28779821520857496],"showlegend":true,"mode":"markers","name":"Cluster 1","zmin":-0.1,"legendgroup":"Cluster 1","marker":{"symbol":"circle","color":"rgba(0, 154, 250, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":4},"zmax":0.1,"y":[0.461614931957824,0.45180850829456887,0.461888155557556,0.39166360741754835,0.38444643675485435,0.45793540608289907,0.49329807361836453,0.3941171348418475,0.3946337682032406,0.44005788086541053,0.4226006341861914,0.4218839497799487,0.3517445400294339,0.39733010052761375,0.4310131013422207,0.4457808165351198,0.4750869526908683,0.3667436729401081,0.40527877429620607,0.35433383565538334,0.42775639949930633,0.4188125571137422,0.3850537746966307,0.463139183006712,0.46271758330129376,0.40704395360400225,0.4360121162773427,0.41330794419597283,0.41417201737841536,0.4593305265107843,0.4565555014240241,0.47364559861486755,0.3792887128414615,0.41942792403279805,0.4849029614028908,0.49789044915358494,0.3808346607611326,0.42150903840973997,0.4609021143027736,0.4391362644884613,0.43934378 ...

# %% [markdown]
# ### Test the clustering on the Santa Travelling Data

# %%
using DataFrames
using CSV
Cities = CSV.read("cities.csv")
head(Cities)
# Out:
# 6×3 DataFrame
# │ Row │ CityId │ X        │ Y        │
# │     │ Int64⍰ │ Float64⍰ │ Float64⍰ │
# ├─────┼────────┼──────────┼──────────┤
# │ 1   │ 0      │ 316.837  │ 2202.34  │
# │ 2   │ 1      │ 4377.41  │ 336.602  │
# │ 3   │ 2      │ 3454.16  │ 2820.05  │
# │ 4   │ 3      │ 4688.1   │ 2935.9   │
# │ 5   │ 4      │ 1010.7   │ 3236.75  │
# │ 6   │ 5      │ 2474.23  │ 1435.51  │

# %%
X = Array{Float64,1}(Cities[:X])   ## x-coordinates of the cities
Y = Array{Float64,1}(Cities[:Y])  ## y-coordinates of the cities
Data = [X';Y']
n = size(Data,2)
# Out:
# 197769

# %%
N_upper = 50 ## The upper bound for the sizes of each group
k = N_upper
## initseeds(:kmcen, X, k) ## initialize the points
@time R = kmeans(Data, k) ##; maxiter = 2000, display=:iter) ## R = Result
# Out:
#   5.546762 seconds (867 allocations: 1.314 GiB, 13.07% gc time)
# KmeansResult{Float64}([2666.96 4483.1 … 3571.19 4478.44; 1533.58 1704.19 … 1799.77 1320.65], [32, 28, 43, 26, 20, 35, 36, 30, 38, 4  …  13, 47, 27, 28, 24, 27, 40, 45, 33, 20], [3258.33, 26448.8, 98428.9, 43328.4, 54944.2, 32592.0, 56854.4, 8153.77, 6217.61, 50956.8  …  21822.8, 43566.2, 21236.5, 8449.82, 21356.2, 10747.5, 85828.4, 7607.28, 32272.4, 15818.7], [5760, 4074, 4489, 3724, 3513, 2557, 3825, 3853, 5958, 5241  …  4518, 3812, 4193, 2132, 5946, 3054, 3051, 3143, 3144, 3672], [5760.0, 4070.0, 4489.0, 3725.0, 3513.0, 2558.0, 3821.0, 3852.0, 5958.0, 5241.0  …  4518.0, 3809.0, 4193.0, 2132.0, 5947.0, 3054.0, 3051.0, 3143.0, 3143.0, 3669.0], 8.64439454588256e9, 100, false)

# %%
A = assignments(R) ## the assignments of the points
N = nclusters(R) ## number of clusters
C = counts(R); ## size of each cluster

# %%
Cluster_Dic = Dict(i=>Int[] for i=1:k)
for i=1:k
    Cluster_Dic[i] = findall(A.==i)
end
Cluster_Dic;

# %%
using StatsBase
sample
# Out:
# sample (generic function with 14 methods)

# %%
N_plot = 10000
Cities_plot = sample(collect(1:n), N_plot, replace = false)
scatter()
for i=1:k
    C_i_plot = intersect(Cluster_Dic[i], Cities_plot)
    scatter!(Data[1,C_i_plot], Data[2,C_i_plot], label = "Cluster $i", markersize = 2)
end
scatter!()
# Out:
#     <div id="c1dfe75c-b9a2-4720-b95d-c8aa9ce0c7bd" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('c1dfe75c-b9a2-4720-b95d-c8aa9ce0c7bd');
#     Plotly.plot(PLOT, [{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x":[4515.40685070572,4427.20558717889,4452.22456028908,4530.36174521505,4528.82921815582,4520.46125354473,4517.16088598593,4463.14977310607,4439.28414282526,4529.29576250876,4429.17383741919,4449.14159365441,4541.11399025241,4444.93630059204,4430.19966877728,4553.05647126615,4512.72391367992,4496.66158219925,4440.31930983028,4510.63984531544,4427.12898486308,4435.10044178392,4430.80132486848,4488.4483679409],"showlegend":true,"mode":"markers","name":"Cluster 1","zmin":-0.1,"legendgroup":"Cluster 1","marker":{"symbol":"circle","color":"rgba(0, 154, 250, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":4},"zmax":0.1,"y":[836.930941892867,776.318793047416,846.986292495131,841.296218592619,784.750397382157,861.445654793644,803.972481367685,783.411758731645,830.308814403161,816.234611356694,880.936866890903,801.862321855904,799.863694923253,850.809480880071,834.619915179422,843.56617674835,882.737063183721,825.493522574277,807.58507613191,774.554584387704,781.884152126235,804.096309805046,841.021590667178,859.256851636305],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x":[589.466377332064,638.57401918816,602.553891352436,534.529314464993,511.171391863463,504.887858333062,614.721490229912,597.09130114842,540.269518756711,511.090125958393,528.900991284511,570.025002756767,652.100176748192,524.380560771958,491.530523801716,504.123920663321],"showlegend":true,"mode":"markers","name":"Cluster 2","zmin":-0.1,"legendgroup":"Cluster 2","marker":{"symbol":"circle","color":"rgba(227, 111, 71, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":4},"zmax":0.1,"y":[2295.61829083187,2286.9317229964,2370.71027738562,2242.41180430568,2373.24208135046,2349.52685232486,2319.64533833967,2351.61342844426,2300.33304435564,2256.70609510626,2313.78910071816,2396.84855098592,2313.68069624866,2256.65926040616,2289.60123482198,2324.79870034013],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x":[3385.88248830268,3402.12875803424,3352.84830082698,3277.34495937169,3303.64567003599,3335.19800521114,3303.12167161243,3298.85936882763,3430.20303722168,3347.61046450165,3367.46508204157,3389.78214149035,3407.76789862138,3481.92403519766,3359.09364284558,3271.78575182671,3354.720713753,3431.90259130365,3324.29313974166,3472.36379387508,3364.2267734336,3322.12334392966,3337.88717454251,3411.55425168483,3426.66049687506],"showlegend":true,"mode":"markers","name":"Cluster 3","zmin":-0.1,"legendgroup":"Cluster 3","marker":{"symbol":"circle","color":"rgba(62, 164, 78, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":4},"zmax":0.1,"y":[3327.37219565163,3202.91850145566,3339.77587758491,3246.83478923892,3375.449322035,3212.51947580604,3295.67659895565,3216.10287112704,3226.73758276317,3252.13697846092,3288.29631358398,3263.39855065697,3191.03341584933,3370.49302661559,3216.14701574212,3243.72991130474,3185.34426269103,3343.38224403759,3254.66979501692,3332.28562490844,3196.00956734467,3192.36488934472,3182.71937086506,3282.42611330088,3361.74903864543],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x":[592.197216347423,559.334520059759,591.104571705526,539.708811823337,564.323551636258,643.551566941494,528.037522355582,599.162945196307,629.404563302526,564.720236844438,564.270237829847,623.052565500929,539.552146797324,658.067998755204,580.99510 ...

# %%
# Out:
# 400

# %%
TooBig = zeros(Int, 0, 2)
for i=1:k
    if C[i]>400
        TooBig = [TooBig; [C[i] i]]
    end
end
sortslices(TooBig, dims = 1)
# Out:
# 234×2 Array{Int64,2}:
#  401  113
#  402  129
#  402  291
#  403   78
#  404   51
#  404  431
#  404  497
#  405   94
#  405  250
#  407  132
#  409  345
#  410  443
#  411  128
#    ⋮
#  668   55
#  672  251
#  681  120
#  692  237
#  692  275
#  709  462
#  718    5
#  727  179
#  727  313
#  738   11
#  742  492
#  762  280

# %%
# Out:
# cannot assign variable Rounding.RoundingMode from module Main
#
# Stacktrace:
#  [1] top-level scope at In[57]:1

# %%
round(Int, C[113]/N_upper, RoundUp)
# Out:
# 2

# %%
using DataFrames
using CSV
Cities = CSV.read("sample_submission.csv")
head(Cities)
tail(Cities)
# Out:
# 6×1 DataFrame
# │ Row │ Path   │
# │     │ Int64⍰ │
# ├─────┼────────┤
# │ 1   │ 197764 │
# │ 2   │ 197765 │
# │ 3   │ 197766 │
# │ 4   │ 197767 │
# │ 5   │ 197768 │
# │ 6   │ 0      │

# %%
using StatsBase
Z = sample(collect(1:n-1), n-1, replace = false)
Z = [0;Z;0] ## The submission must have 0 as head and tail
df = DataFrame([Z], [:Path]); ## store as dataframe type and add the column name :Path
[head(df) tail(df)]
# Out:
# 6×2 DataFrame
# │ Row │ Path   │ Path_1 │
# │     │ Int64  │ Int64  │
# ├─────┼────────┼────────┤
# │ 1   │ 0      │ 118476 │
# │ 2   │ 143685 │ 39929  │
# │ 3   │ 18252  │ 105426 │
# │ 4   │ 58545  │ 20960  │
# │ 5   │ 37262  │ 83643  │
# │ 6   │ 149859 │ 0      │

# %%
CSV.write("Z.csv", df)
# Out:
# "Z.csv"

# %%
tail(df)
# Out:
# 6×1 DataFrame
# │ Row │ Path   │
# │     │ Int64  │
# ├─────┼────────┤
# │ 1   │ 13847  │
# │ 2   │ 137047 │
# │ 3   │ 16211  │
# │ 4   │ 163834 │
# │ 5   │ 16395  │
# │ 6   │ 157835 │
