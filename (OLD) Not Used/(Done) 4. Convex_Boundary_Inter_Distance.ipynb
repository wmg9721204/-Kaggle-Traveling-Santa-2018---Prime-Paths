# %% [markdown]
# ### Goal: Convex_Boundary_Inter_Distance
# **Inputs:**
# 1. G1 = N1 x 2 matrix; each row is a point in group G1
# 2. G2 = N2 x 2 matrix; each row is a point in group G2
# 3. ratio = the ratio in the function "Boundary"
#
# **Output:**
# a dictionary with 3 keys ("Group1", "Group2", "D_min"), whose values are the points in each group achieving the minimum distance and the so-computed minimum distance.

# %%
Pts = rand(50,2)
Centers = rand(5,2)
using Plots
plotly()
scatter(Pts[:,1], Pts[:,2], label = "Points")
scatter!(Centers[:,1], Centers[:,2], label = "Centers")
# Out:
#     <script type="text/javascript">
#         requirejs(["https://cdn.plot.ly/plotly-latest.min.js"], function(p) {
#             window.Plotly = p
#         });
#     </script>
#     <div id="d8f6272e-a350-4185-9eb4-242a093b1fca" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('d8f6272e-a350-4185-9eb4-242a093b1fca');
#     Plotly.plot(PLOT, [{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x":[0.390309683897077,0.21521205418187384,0.29264891211088906,0.7580789124309069,0.9580373754798848,0.014869414780935397,0.023832382452581014,0.12166082709989312,0.4453092072092726,0.5065608272087667,0.279596579448389,0.43696610348097065,0.5390060402782402,0.7646398653236977,0.8599986568271636,0.37160081567182823,0.3723881722495819,0.43207330689404144,0.9770745616472281,0.9469053514712997,0.7070323429391348,0.258175945885019,0.7413613838245394,0.8334798618306991,0.6956225863767391,0.8063564936378653,0.03611321095069542,0.959205278996696,0.4013261237584842,0.0002930712822926118,0.7386303602338995,0.8645353870807988,0.8188281664697703,0.21410910525301663,0.6944006147065436,0.2529005956645003,0.08947475110591974,0.923824281603201,0.5173020315615031,0.8548694492951976,0.23938858986019929,0.25741812103248507,0.08066309942373606,0.9001286843735938,0.005810952403300096,0.6182608823470264,0.2295019110289056,0.39889206303511204,0.8130982683076817,0.366144910757761],"showlegend":true,"mode":"markers","name":"Points","zmin":-0.1,"legendgroup":"Points","marker":{"symbol":"circle","color":"rgba(0, 154, 250, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[0.21480514488582658,0.05935764042883851,0.8031288290734728,0.5655675347977096,0.20758433377576102,0.10560653992999636,0.8025560850841122,0.7968078812098216,0.6791553897017368,0.7373947236656051,0.2424921600962744,0.7681450994569248,0.5380954512970744,0.4667283157205886,0.27137393620552475,0.20459473839181608,0.3988842481604882,0.5726424452496552,0.24207404144563327,0.16733898401518288,0.49236979251249235,0.9393173412096454,0.8834216170832612,0.5497189684679997,0.3083082871065561,0.25695269801247256,0.10552597685609788,0.90526830798345,0.29990740671657723,0.8700049735774631,0.7067726048836904,0.1428220077963016,0.5421913484843421,0.5306960320618799,0.9481945033929273,0.3489922905100433,0.04544498582105749,0.5077757176430509,0.4104966922264712,0.7456913832231007,0.22649550921276096,0.5083704348330587,0.4677540983607764,0.9666380498355824,0.8514220644247152,0.9822235700146609,0.5339162633304584,0.34313390883901596,0.3974475757704554,0.13293553419532644],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null,null,null,null],"x":[0.8316533018876251,0.05345175545982306,0.16738150926182604,0.9457853152413673,0.9779102536564979],"showlegend":true,"mode":"markers","name":"Centers","zmin":-0.1,"legendgroup":"Centers","marker":{"symbol":"circle","color":"rgba(227, 111, 71, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[0.2636129823541049,0.8991815877594811,0.34192033301695335,0.5089581708776216,0.17789812102988534],"type":"scatter","hoverinfo":"text"}], {"showlegend":true,"xaxis":{"showticklabels":true,"gridwidth":0.5,"tickvals":[0.0,0.25,0.5,0.75,1.0],"visible":true,"ticks":"inside","range":[-0.029035444188933543,1.007238769127724],"domain":[0.05100612423447069,0.9934383202099737],"tickmode":"array","linecolor":"rgba(0, 0, 0, 1.000)","showgrid":true,"title":"","mirror":false,"tickangle":0,"showline":true,"gridcolor":"rgba(0, 0, 0, 0.100)","titlefont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":15},"tickcolor":"rgb(0, 0, 0)","ticktext":["0.00","0.25","0.50","0.75","1.00"],"zeroline":false,"type":"-","tickfont":{"color":"rgba(0, 0, 0, 1.000)","family":"sans-serif","size":11},"zerolinecolor":"rgba(0, 0, 0, 1.000)","anchor":"y1"},"paper_bgcolor":"rgba(255, 255, 255, 1.000)","annotations":[],"height":400,"margin":{"l":0,"b":20,"r":0,"t":20},"plot_bgcolor":"rgba(255, 255, 255, 1.000)","yaxis":{"showticklabels":true,"gridwidth":0.5,"tickval ...
#     </script>

# %%
using QHull

p = rand(6000,2)
@time ch = chull(p)
ch.points         # original points
ch.vertices       # indices to line segments forming the convex hull
ch.simplices;      # the simplexes forming the convex hull
## show(ch)
# Out:
#   0.005709 seconds (1.35 k allocations: 135.000 KiB)

# %%
normal_b
# Out:
# 2-element Array{Float64,1}:
#  -0.9865478606340647
#   0.7944371599677893

# %%
Bds = ch.simplices
plot()
for b = 1:length(Bds)
    plot!(p[Bds[b],:][:,1], p[Bds[b],:][:,2])
end
plot!()
# Out:
#     <div id="df6c7f99-4d05-47ad-ac3d-2ef314393244" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('df6c7f99-4d05-47ad-ac3d-2ef314393244');
#     Plotly.plot(PLOT, [{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[0.9985706331000759,0.9942337209841545],"showlegend":true,"mode":"lines","name":"y1","zmin":-0.1,"legendgroup":"y1","zmax":0.1,"line":{"color":"rgba(0, 154, 250, 1.000)","shape":"linear","dash":"solid","width":1},"y":[0.20413347313228658,0.007685860350089779],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[0.9230058398061214,0.050289394789383435],"showlegend":true,"mode":"lines","name":"y2","zmin":-0.1,"legendgroup":"y2","zmax":0.1,"line":{"color":"rgba(227, 111, 71, 1.000)","shape":"linear","dash":"solid","width":1},"y":[0.000936673952516065,0.00011574124293289856],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[0.0006005869055119017,0.00022143651240980056],"showlegend":true,"mode":"lines","name":"y3","zmin":-0.1,"legendgroup":"y3","zmax":0.1,"line":{"color":"rgba(62, 164, 78, 1.000)","shape":"linear","dash":"solid","width":1},"y":[0.14201731574757637,0.7465007776377086],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[0.0006005869055119017,0.003201084832767709],"showlegend":true,"mode":"lines","name":"y4","zmin":-0.1,"legendgroup":"y4","zmax":0.1,"line":{"color":"rgba(195, 113, 210, 1.000)","shape":"linear","dash":"solid","width":1},"y":[0.14201731574757637,0.026101715645771684],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[0.0095186641567091,0.050289394789383435],"showlegend":true,"mode":"lines","name":"y5","zmin":-0.1,"legendgroup":"y5","zmax":0.1,"line":{"color":"rgba(172, 142, 24, 1.000)","shape":"linear","dash":"solid","width":1},"y":[0.015244581802591917,0.00011574124293289856],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[0.0095186641567091,0.003201084832767709],"showlegend":true,"mode":"lines","name":"y6","zmin":-0.1,"legendgroup":"y6","zmax":0.1,"line":{"color":"rgba(0, 170, 174, 1.000)","shape":"linear","dash":"solid","width":1},"y":[0.015244581802591917,0.026101715645771684],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[0.9995627695568594,0.9999133888692657],"showlegend":true,"mode":"lines","name":"y7","zmin":-0.1,"legendgroup":"y7","zmax":0.1,"line":{"color":"rgba(237, 94, 147, 1.000)","shape":"linear","dash":"solid","width":1},"y":[0.3695743198713646,0.8431013534914105],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[0.9995627695568594,0.9985706331000759],"showlegend":true,"mode":"lines","name":"y8","zmin":-0.1,"legendgroup":"y8","zmax":0.1,"line":{"color":"rgba(198, 130, 37, 1.000)","shape":"linear","dash":"solid","width":1},"y":[0.3695743198713646,0.20413347313228658],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[0.9611217768042055,0.9230058398061214],"showlegend":true,"mode":"lines","name":"y9","zmin":-0.1,"legendgroup":"y9","zmax":0.1,"line":{"color":"rgba(0, 169, 141, 1.000)","shape":"linear","dash":"solid","width":1},"y":[0.0032973096871700136,0.000936673952516065],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[0.0008215848767691991,0.00022143651240980056],"showlegend":true,"mode":"lines","name":"y10","zmin":-0.1,"legendgroup":"y10","zmax":0.1,"line":{"color":"rgba(142, 151, 30, 1.000)","shape":"linear","dash":"solid","width":1},"y":[0.9100002493194195,0.7465007776377086],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null],"x":[0.0008215848767691991,0.0028689315302947715],"showlegend":true,"mode":"lines","name":"y11","zmin":-0.1,"legendgroup":"y11","zmax":0.1,"line":{"color":"rgba(0,  ...

# %%
using LinearAlgebra ## for "dot"
ratio = 1/50
## plot for illustration
## scatter(p[:,1], p[:,2], markersize = 1, label = "points")
## scatter!(p[ch.vertices,1], p[ch.vertices,2], label = "vertices")
Bds = ch.simplices 
Bd_Pts = Int[]
for b = 1:length(Bds)
    vector_b = p[Bds[b][1],:]-p[Bds[b][2],:] ## the vector of the boundary b
    normal_b = [-vector_b[2], vector_b[1]] ## a vector normal to the boundary b vector
    ## move vector_b orthogonally and find out the intersected bar
    bd_b_para = p*vector_b 
    Range_b_para = p[ch.simplices[b],:]*vector_b
    pts_b_para = findall((p*vector_b.<=maximum(Range_b_para)).&(minimum(Range_b_para).<=p*vector_b))
    N = Int(round(ratio*length(pts_b_para)))
    Values_Labels = sortslices([p[pts_b_para,:]*normal_b pts_b_para], dims = 1)
    Values = Values_Labels[:,1]
    Labels = Values_Labels[:,2]
    Bd_Pts_N = 0
    if abs((Values[1]-Values[2])/Values[2])<1.0e-5
        Bd_Pts_N = Array{Int,1}(Labels[1:N])
    else
        Bd_Pts_N = Array{Int,1}(Labels[length(Labels)-N+1:length(Labels)])
    end
    Bd_Pts = union(Bd_Pts, Bd_Pts_N)
    ## plot for sanity check
    ## plot!(p[Bds[b],:][:,1], p[Bds[b],:][:,2], label = "Bd $b")
    ## scatter!(p[Bd_Pts_N,1], p[Bd_Pts_N,2], label = "Bd $b points")
end
## scatter!()
# Out:
#     <div id="6ee6fc1e-a97c-4dbf-96bd-df92839bb2bc" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('6ee6fc1e-a97c-4dbf-96bd-df92839bb2bc');
#     Plotly.plot(PLOT, [{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,nul ...

# %%
G1 = p[Bd_Pts,:]
# Out:
# 447×2 Array{Float64,2}:
#  0.998571  0.204133
#  0.994234  0.00768586
#  0.998208  0.192265
#  0.994276  0.0380312
#  0.99207   0.0199779
#  0.990908  0.0131281
#  0.991446  0.0532527
#  0.993894  0.176328
#  0.989554  0.0696217
#  0.988762  0.0626323
#  0.986338  0.012406
#  0.988483  0.122136
#  0.985169  0.013992
#  ⋮
#  0.378143  0.994879
#  0.393624  0.99496
#  0.365081  0.995066
#  0.41956   0.996673
#  0.387986  0.997431
#  0.451204  0.997506
#  0.324915  0.997679
#  0.452715  0.99804
#  0.344065  0.998802
#  0.32475   0.999008
#  0.393849  0.999023
#  0.350226  0.999346

# %%
?find
# Out:
# search: findmin findmax findall findprev findnext findmin! findmax! findlast
#
# Couldn't find find
# Perhaps you meant bind, sind, fill, font, fd, fld, cond, pinv, Cint, asind or in
#   No documentation found.
#
#   Binding find does not exist.

# %%
G1 = rand(500,2)
G2 = rand(600,2)
@time Dist2 = [sum((G1[i,:]-G2[j,:]).^2) for i=1:size(G1,1), j = 1:size(G2,1)] ## distance^2
@time G1_G2_Min = findmin(Dist2)
Min_Index = G1_G2_Min[2]
Min_Dist = sqrt(G1_G2_Min[1])
# Out:
#   1.013138 seconds (3.97 M allocations: 166.378 MiB, 3.55% gc time)
#   0.001162 seconds (5 allocations: 192 bytes)
# 0.00045287259214233364

# %%
using LinearAlgebra ## "dot"
using QHull ## "chull"
## using Plots
## plotly()

function Boundary(G::Array{Float64,2}, ratio = 0.05::Float64) ## G = Group (of points), N x 2
    @time ch = chull(G)
    ## ch.points         # original points
    ## ch.vertices       # indices to line segments forming the convex hull
    ## ch.simplices;      # the simplexes forming the convex hull
    ## show(ch) 
        
        
    ## ratio = 1/50
    ## plot for illustration
    ## scatter(G[:,1], G[:,2], markersize = 1, label = "points")
    ## scatter!(G[ch.vertices,1], G[ch.vertices,2], label = "vertices")
    Bds = ch.simplices 
    Bd_Pts = Int[]
    for b = 1:length(Bds)
        vector_b = G[Bds[b][1],:]-G[Bds[b][2],:] ## the vector of the boundary b
        normal_b = [-vector_b[2], vector_b[1]] ## a vector normal to the boundary b vector
        ## move vector_b orthogonally and find out the intersected bar
        bd_b_para = G*vector_b 
        Range_b_para = G[ch.simplices[b],:]*vector_b
        pts_b_para = findall((G*vector_b.<=maximum(Range_b_para)).&(minimum(Range_b_para).<=G*vector_b))
        N = Int(round(ratio*length(pts_b_para)))
        Values_Labels = sortslices([G[pts_b_para,:]*normal_b pts_b_para], dims = 1)
        Values = Values_Labels[:,1]
        Labels = Values_Labels[:,2]
        Bd_Pts_N = 0
        if abs((Values[1]-Values[2])/Values[2])<1.0e-5
            Bd_Pts_N = Array{Int,1}(Labels[1:N])
        else
            Bd_Pts_N = Array{Int,1}(Labels[length(Labels)-N+1:length(Labels)])
        end
        Bd_Pts = union(Bd_Pts, Bd_Pts_N)
        ## plot for sanity check
        ## plot!(G[Bds[b],:][:,1], G[Bds[b],:][:,2], label = "Bd $b")
        ## scatter!(G[Bd_Pts_N,1], G[Bd_Pts_N,2], label = "Bd $b points")
    end
    ## scatter!()
    Bd_Pts
end
# Out:
# Boundary (generic function with 2 methods)

# %%
GG = rand(1000,2)
Boundary(GG)
# Out:
#   0.004820 seconds (995 allocations: 46.281 KiB)
# 172-element Array{Int64,1}:
#  188
#  943
#  905
#  987
#  926
#  566
#  930
#  193
#  399
#  698
#  725
#  889
#  842
#    ⋮
#   88
#  859
#  166
#   51
#  326
#  231
#  886
#  654
#  668
#  914
#   25
#  894

# %%
## computes by brute force the minimum pairwise distances between two groups of points
## Input: G1, G2, N x d
## Output: 
## (1) the pair of points in G1 and G2, resp, achieving the minimum
## (2) the minimum distance
function Inter_Distance(G1::Array{Float64,2}, G2::Array{Float64,2})
    @time Dist2 = [sum((G1[i,:]-G2[j,:]).^2) for i=1:size(G1,1), j = 1:size(G2,1)] ## distance^2
    @time G1_G2_Min = findmin(Dist2)
    ## Min_Index = G1_G2_Min[2]
    ## Min_Dist = sqrt(G1_G2_Min[1])
    return (G1_G2_Min[2], sqrt(G1_G2_Min[1]))
end
# Out:
# Inter_Distance (generic function with 1 method)

# %%
## This function computes an approximate minimum distance bewteen two groups of points
## Inputs: 
## (1) G1 = N1 x 2 matrix; each row is a point in group G1
## (2) G2 = N2 x 2 matrix; each row is a point in group G2
## (3) ratio = the ratio in the function "Boundary"
## Output:
## a dictionary with 3 keys ("Group1", "Group2", "D_min")
## whose values are the points in each group achieving the minimum distance 
## and the so-computed minimum distance.
function Convex_Boundary_Inter_Distance(G1::Array{Float64,2}, G2::Array{Float64,2}, ratio = 0.05::Float64)
    Bd1_Label = Boundary(G1, ratio)
    Bd2_Label = Boundary(G2, ratio)
    G1_Bd1 = G1[Bd1_Label,:]
    G2_Bd2 = G2[Bd2_Label,:]
    (NewLabel, Dist_Min) = Inter_Distance(G1_Bd1, G2_Bd2)
    return Dict("Group1"=>Bd1_Label[NewLabel[1]], "Group2"=>Bd2_Label[NewLabel[2]], "D_min"=>Dist_Min)
end
# Out:
# Convex_Boundary_Inter_Distance (generic function with 1 method)

# %% [markdown]
# ## Test the function

# %%
H1 = rand(300, 2)
H2 = rand(500, 2).+[1 1]
scatter(H1[:,1], H1[:,2], label = "Group 1")
scatter!(H2[:,1], H2[:,2], label = "Group 2")
CBID = Convex_Boundary_Inter_Distance(H1,H2)
# Out:
#   0.002909 seconds (753 allocations: 28.484 KiB)
#   0.002689 seconds (711 allocations: 30.375 KiB)
#   0.004248 seconds (18.23 k allocations: 1.474 MiB)
#   0.000027 seconds
# Dict{String,Real} with 3 entries:
#   "Group2" => 88
#   "Group1" => 7
#   "D_min"  => 0.0848971

# %%
scatter!([H1[CBID["Group1"],1]], [H1[CBID["Group1"],2]], label = "Point for Group 1")
scatter!([H2[CBID["Group2"],1]], [H2[CBID["Group2"],2]], label = "Point for Group 2")
# Out:
#     <div id="5de165e1-3376-47e8-ab72-0baf3e6339bb" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('5de165e1-3376-47e8-ab72-0baf3e6339bb');
#     Plotly.plot(PLOT, [{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x":[0.46292479850451596,0.4771668582593567,0.8028940480239457,0.3128657459052149,0.75845556169746,0.3102383800650159,0.9483502438023927,0.27890852003301503,0.42249306920823515,0.8638295607644033,0.5173357745325877,0.465194778140287,0.884588048648929,0.24342105473622588,0.8499075133174019,0.3759436857822436,0.7407978906050432,0.6963810266719301,0.8896431504353155,0.7622877252925901,0.046634191495861455,0.13103651605980238,0.3704950145471064,0.47225188682873154,0.6852814965966225,0.5078490960523525,0.18691424540516022,0.8724866121293402,0.4831291467756478,0.33530313708211246,0.39768538055570946,0.12458747642362544,0.6731732164160689,0.9581496783440104,0.19408166646060065,0.06484366659938656,0.3175050959300747,0.18447598095911344,0.4178425459240458,0.8517267830134057,0.42967239200824703,0.6356985691151855,0.9811553578443339,0.9794893504309179,0.8503091029400474,0.37493354079132324,0.4204217757664528,0.331204276372157,0.415218790329432,0.24817115327457784,0.9957595034203279,0.8778083369232923,0.04381250616353061,0.6921298145823449,0.9784568282932435,0.3334149467748089,0.32599036635651,0.9346416581315526,0.5907350914041043,0.21038283486461928,0.6947672635060691,0.1953609114303767,0.026567358508151617,0.5753878278900233,0.7361811552533837,0.22442236236086255,0.3399418877312861,0.37587112256618305,0.21367251848197322,0.4302900246166188,0.06261890070114662,0.07572959508923627,0.050146714619153876,0.9142904316594833,0.327530978748239,0.42218874259600647,0.46766443470850816,0.0705597114010943,0.006881352176293598,0.04352760006401546,0.6648426008227768,0.12641293479636317,0.22318186083478975,0.8949330981504799,0.8534845519035554,0.9743437858169888,0.7058675641541219,0.0050519606725916155,0.7791357920010589,0.18238045690200488,0.7872643787204783,0.1755209147177872,0.6008885742492365,0.9650697894329003,0.6059516663031115,0.7376148721177904,0.24397581347447872,0.9015843155222107,0.39397421825689505,0.7077520414102505,0.3383194002708221,0.47960059611674377,0.9562112224517081,0.44445829732694664,0.5527740076097087,0.4053061790167496,0.19065076454450947,0.7216831625017497,0.8135335665427166,0.8989469778857524,0.701391616744075,0.571134313009865,0.04681658391814514,0.03383105781698448,0.8145205495403116,0.45797646135779235,0.8208055750696992,0.45731731349946236,0.36387917271255255,0.503628713619324,0.14703573199148923,0.8340417490193202,0.9492682726192712,0.6889015364770279,0.661853450643188 ...

# %%
include("src\\Convex_Boundary_Inter_Distance.jl")
# Out:
# ┌ Info: Recompiling stale cache file C:\Users\wmg97_000\.julia\compiled\v1.0\QHull\FsLaA.ji for QHull [a8468747-bd6f-53ef-9e5c-744dbc5c59e7]
# └ @ Base loading.jl:1190
# Convex_Boundary_Inter_Distance (generic function with 2 methods)

# %%
Inter_Distance
# Out:
# Inter_Distance (generic function with 1 method)

# %%
Boundary
# Out:
# Boundary (generic function with 2 methods)

# %%
Convex_Boundary_Inter_Distance
# Out:
# Convex_Boundary_Inter_Distance (generic function with 2 methods)

# %%
H1 = rand(10000, 2)
H2 = rand(10000, 2).+[1 1];

# %%
CBID = @time Convex_Boundary_Inter_Distance(H1,H2)
# Out:
#   2.210439 seconds (14.59 M allocations: 1.173 GiB, 10.08% gc time)
# Dict{String,Real} with 3 entries:
#   "Group2" => 10000
#   "Group1" => 6458
#   "D_min"  => 0.00869799

# %%
@time Inter_Distance(H1,H2)
# Out:
#   7.884744 seconds (75.00 M allocations: 5.923 GiB, 9.11% gc time)
#   0.063881 seconds
#   7.950199 seconds (75.00 M allocations: 5.923 GiB, 9.03% gc time)
# (CartesianIndex(2267, 3911), 0.03344129473255766)
