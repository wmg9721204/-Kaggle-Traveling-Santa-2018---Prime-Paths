# %% [markdown]
# ## Read the data

# %%
using DataFrames
using CSV
Cities = CSV.read("cities.csv")
head(Cities)
# Out:
# 6×3 DataFrame
# │ Row │ CityId │ X        │ Y        │
# │     │ Int64⍰ │ Float64⍰ │ Float64⍰ │
# ├─────┼────────┼──────────┼──────────┤
# │ 1   │ 0      │ 316.837  │ 2202.34  │
# │ 2   │ 1      │ 4377.41  │ 336.602  │
# │ 3   │ 2      │ 3454.16  │ 2820.05  │
# │ 4   │ 3      │ 4688.1   │ 2935.9   │
# │ 5   │ 4      │ 1010.7   │ 3236.75  │
# │ 6   │ 5      │ 2474.23  │ 1435.51  │

# %%
X = Array{Float64,1}(Cities[:X])   ## x-coordinates of the cities
Y = Array{Float64,1}(Cities[:Y])  ## y-coordinates of the cities
Data = [X';Y']
CityId = Array{Int,1}(Cities[:CityId]);

# %% [markdown]
# ## Find out the prime cities

# %%
using Primes
PrimeCities = findall(isprime.(collect(1:size(Data,2)).-1));

# %% [markdown]
# ## Basic Plan for TSP (Travelling Salesman Problem):
# 1. Use **KDE** to find the P points that represent the P densest places (P means peaks) <br>
# 2. Use **nearest neighbor principle** to partition all cities into clusters <br>
# 3. Use **ant colony optimization (ACO)** to figure out approximate shortest travelling path inside each cluster <br>
# 4. Combine the local paths inside each cluster to obtain the global path

# %% [markdown]
# ### 1. Compute the KDE of cities

# %%
include("src\\f_KDE.jl")
# Out:
# Functions 'NormalDensity', 'f_KDE' imported

# %%
## Kernels = [NormalDensity(d, Data[i,:], H_MS) for i=1:n]
f_H = f_KDE(Data, 5000)
# Out:
# f_H (generic function with 1 method)

# %% [markdown]
# ### 2. Find out the Modes of f_KDE

# %%
include("src\\Mode.jl")
Range = [minimum(Data[1,:]) maximum(Data[1,:]); minimum(Data[2,:]) maximum(Data[2,:])]
k = 10
N = 5000;

# %%
@time Peaks = Mode(f_H, Range, N = N, k = k);
# Out:
# 104.554000 seconds (601.31 M allocations: 61.809 GiB, 8.41% gc time)

# %%
using JLD

# %% [markdown]
# ### 3. Compute the clusters

# %%
include("src\\VCluster.jl")
# Out:
# VCluster

# %%
Nc = length(Peaks) ## number of centers (peaks/clusters)
Cts = [[Peaks[i][1] for i=1:Nc]';[Peaks[i][2] for i=1:Nc]'] ## Cts = Centers
Cluster_Dic = VCluster(Cts, Data);

# %%
c_NP = 0 ## Cluster number of north pole
for c = 1:Nc
    if 1 in Cluster_Dic[c]
       c_NP = c
    end
end
c_NP
# Out:
# 16

# %%
for k = 1:Nc
    println("CLuster $k size: $(length(Cluster_Dic[k]))")
end
sum([length(Cluster_Dic[k]) for k=1:Nc])
# Out:
# CLuster 1 size: 8933
# CLuster 2 size: 16510
# CLuster 3 size: 3605
# CLuster 4 size: 4299
# CLuster 5 size: 3423
# CLuster 6 size: 6103
# CLuster 7 size: 4315
# CLuster 8 size: 2573
# CLuster 9 size: 3546
# CLuster 10 size: 10522
# CLuster 11 size: 5982
# CLuster 12 size: 3412
# CLuster 13 size: 18071
# CLuster 14 size: 8682
# CLuster 15 size: 4456
# CLuster 16 size: 9927
# CLuster 17 size: 2678
3682.52409752024,3845.29732179604,4277.83807565563,4052.01907062796,3541.34004177938,4253.04869583515,3599.47857404238,4294.75441429749,4008.30841380256,4021.35712062914,4260.57125885328,3409.00982614589,4253.21923176183,3803.30165380545,3683.35408229627,4348.06478291211,4167.20948509897,4237.92856739573,4154.97619133758,3482.01406745704,3790.96244765516,4180.44774812078,4135.45506306938,4129.29969396634,3673.60926200169,4083.04945425552,3912.65600568434,4309.27207996342,4166.25519844571,4244.14849740843,4154.68733607948,4141.03752872688,3414.43156923286,3536 ...

# %% [markdown]
# ### Cut the cluster containing NP into two subclusters

# %%
include("src\\CutHalf.jl")
# Out:
# CutHalf

# %%
CH = CutHalf(Data[:,Cluster_Dic[c_NP]], 1) ## cut the cluster containing NP into half
C_NP_Index = Cluster_Dic[c_NP] ## recall the indices in the cluster
Cluster_Dic[0] = sort(C_NP_Index[CH["With Center"]]) ## the subcluster containing NP
Cluster_Dic[c_NP] = sort(C_NP_Index[CH["Without Center"]]); ## the other subcluster

# %%
using Plots
plotly()
Nr = 5000 ## number of random cities
RandomCities = sample(collect(1:size(Data,2)), Nr, replace = false)
scatter([Data[1,1]], [Data[2,1]], label = "North Pole")
@time for c = 0:Nc
    Cluster_k_Plot = intersect(RandomCities, Cluster_Dic[c])
    scatter!(X[Cluster_k_Plot], Y[Cluster_k_Plot], markersize = 1.5, label = "Cluster $c")   
end
scatter!(Cts[1,:], Cts[2,:], label = "Peaks of KDE using k = $k")
# Out:
#   0.163637 seconds (101.20 k allocations: 13.183 MiB, 6.11% gc time)
#     <div id="8e48b130-ef77-4c0d-83bc-642d840f874c" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('8e48b130-ef77-4c0d-83bc-642d840f874c');
#     Plotly.plot(PLOT, [{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null],"x":[316.836739061509],"showlegend":true,"mode":"markers","name":"North Pole","zmin":-0.1,"legendgroup":"North Pole","marker":{"symbol":"circle","color":"rgba(0, 154, 250, 1.000)","line":{"color":"rgba(0, 0, 0, 1.000)","width":1},"size":8},"zmax":0.1,"y":[2202.34070733524],"type":"scatter","hoverinfo":"text"},{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x":[1283.58081029181,941.351388276418,1308.19452036294,971.176641297639,1405.24049203973,1130.19696477083,966.852772843109,609.213339294487,1346.11479296905,1170.86508734682,1202.09734057184,1108.53579996535,836.627065568459,1284.62602913117,777.646260718796,914.423760428854,1349.00118012541,873.900472000704,908.264500185366,999.723048366938,943.197749453015,1116.83892527706,449.242477620397,547.761301841963,1044.37042231266,565.617549372025,1400.7098525898,717.708967871465,698.604357395447,1294.83800686763,1090.83981395572,1252.81317642173,969.557209907989,1304.87887481944,1066.60659933943,910.639514457396,297.346294369667,1108.86057405369,1340.64927336035,693.380439443857,982.298057471293,1381.26750240388,840.406111294209,1365.75521830666,1184.70710812361,1197.70424938114,1074.28752490493,1144.82502454404,776.122378067063,898.601028030043,1164.3678780516,289.266330386704,1104.04032417547,876.505695569812,916.281028536412,499.782912577163,636.887406774809,960.064871603926,852.54146097861,1297.34019891479,1041.80795097856,1409.65779753415,949.292987837442,814.743392594223,1346.34704738228,1116.51010297952,539.253046412656,1319.2139160698,436.966907599576,422.294576914464,1328.90834318318,933.926181753648,1109.34171533784,1002.07851127441,1162.16437033352,1361.63681053603,641.436942760663,665.158902199484,1114.62357717617,824.797452719756,1044.30440054675,962.630255479261,1171.14312485033,950.375846367008,1199.44477040855,1247.48106334282,1192.73104367359,963.373853065405,1254.40000508134,847.316145560787,1419.47300451592,1231.15492722491,978.42061035703,702.5988232036,875.099135567614,540.120557352389,992.479168042156,1408.06435692463,1196.04318741941,1224.94613281278,1179.85031257489,1283.68264027589,700.379068483639,1245.96931268394,861.345315568056,547.863853614946,1046.26391919551,1047.13285006613,779.796955904158,432.67172440598,1111.77046057066,1380.28564374062,1102.52791382956,626.290848793598,1058.98341167534,1075.54400025548,697.839965553,942.607448344614,1138.7479760136,669.731336739141,1118.09956658885,627.763498197502,1074.53532689121,1132.10301931014,887.80545371126,1101.40957055349,1205.22698755065,1114.19962244974,971.097027971164,677.246240736305,991.782182731138,1403.1114982269,1135.25933925696,1284.28312155841,1263.6110681038,633.359523881377,1355.91014694907,938.77336761771,1075.53120628695,892.350532180301,1018.01380327447,1174. ...

# %% [markdown]
# ### 4. Compute the inter-distances between clusters
# Difficulty: computing using brute force is very computational costly

# %% [markdown]
# ### An alternative solution in my mind is to
# 1. compute the convex hull of each cluster, and then
# 2. use the boundary information to reduce redundant computations.

# %%
include("src\\Convex_Boundary_Inter_Distance.jl")
# Out:
# Convex_Boundary_Inter_Distance (generic function with 2 methods)

# %%
Dist_C = zeros(Nc+1,Nc+1)
@time for k = 0:Nc-1
    for l = k+1:Nc
        C_k = Cluster_Dic[k] ## cluster k
        G_k = [X[C_k] Y[C_k]] ## coordinates of cluster k
        C_l = Cluster_Dic[l] ## cluster l
        G_l = [X[C_l] Y[C_l]] ## coordinates of cluster l
        Int_Dist = Convex_Boundary_Inter_Distance(G_k, G_l) ## Int_Dist = inter distance
        Dist_C[k+1,l+1] = Int_Dist["D_min"]
        Dist_C[l+1,k+1] = Int_Dist["D_min"]
    end
end
Dist_C

# %%
Dist_C

# %%
## 
Cluster_Dic[k][Int_Dist["Group1"]]
Cluster_Dic[l][Int_Dist["Group2"]]
scatter(X[Cluster_Dic[k]], Y[Cluster_Dic[k]], markersize = 1, label = "Cluster $k")
scatter!(X[Cluster_Dic[l]], Y[Cluster_Dic[l]], markersize = 1, label = "Cluster $l")
scatter!([X[Cluster_Dic[k][Int_Dist["Group1"]]]], [Y[Cluster_Dic[k][Int_Dist["Group1"]]]], label = "CLosest Point $k")
scatter!([X[Cluster_Dic[l][Int_Dist["Group2"]]]], [Y[Cluster_Dic[l][Int_Dist["Group2"]]]], label = "CLosest Point $l")
# Out:
#     <div id="f6980041-2081-443d-b6a5-8ff53641fb40" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('f6980041-2081-443d-b6a5-8ff53641fb40');
#     Plotly.plot(PLOT, [{"xaxis":"x1","colorbar":{"title":""},"yaxis":"y1","text":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,nul ...

# %%
Dist_C
# Out:
# 38×38 Array{Float64,2}:
#     0.0      2405.86     2235.37     …   909.047    1326.7      2172.98
#  2405.86        0.0        12.2039       778.055     118.0         6.32075
#  2235.37       12.2039      0.0          283.299     291.567     212.466
#  1555.06      901.314     118.779          4.31932   705.948    1017.09
#  4590.27     1251.65     1679.64        2837.43     2281.19     1811.05
#  2844.13       99.3805      4.4391   …   920.572     870.637     762.418
#  3491.75     1503.74     1183.34        1647.15     2167.57     2099.8
#  3116.32      916.016     529.017       1158.47     1513.42     1444.83
#   604.539    1939.5      2093.67         915.232    1026.19     1292.6
#  2205.78     1500.96     1869.74        1655.86     1084.57      915.56
#   952.855    1399.05      799.304    …     3.99957   676.913    1435.59
#  1780.46      779.581    1011.37         907.485     204.72       39.3548
#   380.39     2578.93     2691.7         1399.47     1566.62     2015.71
#     ⋮                                ⋱     ⋮
#  2628.43      891.722    1376.78        1524.39      700.881     511.217
#  2361.5      1030.99      324.568        455.365    1120.4      1229.65
#     3.30647  2288.09     2241.55         882.495    1228.72     1869.61
#  3229.79        7.77249   308.036       1466.28      948.176     611.587
#  3340.88      249.538     959.85     …  1878.91     1148.24      493.868
#  1657.21        8.75873     3.75086        4.32836     4.16104    18.0133
#  1632.73     1962.5      2141.48        1283.53     1271.81     1245.35
#     3.66538  2397.43     2083.34         852.594    1384.78     2290.91
#  3367.89      460.055     482.234       1405.68     1308.1      1144.94
#   909.047     778.055     283.299    …     0.0         4.85054   724.339
#  1326.7       118.0       291.567          4.85054     0.0         7.23126
#  2172.98        6.32075   212.466        724.339       7.23126     0.0

# %%
include("ACO_p_and_ACO_d.jl")
# Out:
# ACO_d (generic function with 6 methods)

# %%
Dist_C2 = Dist_C./maximum(Dist_C)
# Out:
# 38×38 Array{Float64,2}:
#  0.0          0.500138    0.464696     …  0.275799     0.451726
#  0.500138     0.0         0.002537        0.0245302    0.00131398
#  0.464696     0.002537    0.0             0.0606119    0.0441681
#  0.323271     0.187368    0.0246922       0.146755     0.211436
#  0.954242     0.260197    0.349169        0.474221     0.376488
#  0.591248     0.0206596   0.000922817  …  0.180991     0.158494
#  0.725877     0.312603    0.245996        0.450602     0.436515
#  0.647832     0.190425    0.109974        0.314616     0.300356
#  0.125674     0.403191    0.43524         0.213328     0.26871
#  0.458546     0.312025    0.388687        0.225465     0.19033
#  0.198083     0.29084     0.166162     …  0.140719     0.298436
#  0.370128     0.162062    0.210246        0.0425578    0.00818123
#  0.0790768    0.536118    0.55956         0.325675     0.419033
#  ⋮                                     ⋱
#  0.546408     0.185374    0.286209        0.145702     0.106274
#  0.490917     0.214325    0.0674724       0.232913     0.255625
#  0.000687361  0.475657    0.465981        0.25543      0.38866
#  0.67142      0.00161577  0.0640357       0.19711      0.127139
#  0.694515     0.0518749   0.199537     …  0.2387       0.102667
#  0.344507     0.0018208   0.000779742     0.000865011  0.00374467
#  0.339418     0.407973    0.445178        0.264388     0.258888
#  0.000761973  0.498387    0.433093        0.287873     0.476243
#  0.700129     0.095638    0.100249        0.271932     0.238015
#  0.188976     0.161745    0.0588933    …  0.00100835   0.150578
#  0.275799     0.0245302   0.0606119       0.0          0.00150326
#  0.451726     0.00131398  0.0441681       0.00150326   0.0

# %%
O = 3
G = 3
(L,P) = ACO_d(Dist_C2, O, G)
# Out:
# (0.4833430284656327, [3, 32, 37, 36, 22, 18, 9, 21, 13, 29  …  27, 24, 38, 20, 17, 12, 10, 33, 23, 3])

# %%
scatter(NewSample[Peaks,:][:,1], NewSample[Peaks,:][:,2], label = "Peaks")
scatter!()
plot!(NewSample[Peaks,:][P, 1], NewSample[Peaks,:][P, 2], label = "Shortest path, Length = $(round(L,digits = 2))")
# Out:
#     <div id="4dee05f4-37aa-4d29-950f-c1e882e66f25" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById